# %%
# Import pandas 
import pandas as pd
import numpy as np

# Read in white wine data 
white = pd.read_csv("http://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-white.csv", sep=';')

# Read in red wine data 
red = pd.read_csv("http://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv", sep=';')

# %%
# Print info on white wine
print(white.info())

# Print info on red wine
print(red.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
# fixed acidity           4898 non-null float64
# volatile acidity        4898 non-null float64
# citric acid             4898 non-null float64
# residual sugar          4898 non-null float64
# chlorides               4898 non-null float64
# free sulfur dioxide     4898 non-null float64
# total sulfur dioxide    4898 non-null float64
# density                 4898 non-null float64
# pH                      4898 non-null float64
# sulphates               4898 non-null float64
# alcohol                 4898 non-null float64
# quality                 4898 non-null int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
# fixed acidity           1599 non-null float64
# volatile acidity        1599 non-null float64
# citric acid             1599 non-null float64
# residual sugar          1599 non-null float64
# chlorides               1599 non-null float64
# free sulfur dioxide     1599 non-null float64
# total sulfur dioxide    1599 non-null float64
# density                 1599 non-null float64
# pH                      1599 non-null float64
# sulphates               1599 non-null float64
# alcohol                 1599 non-null float64
# quality                 1599 non-null int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB
# None

# %%
white.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# min       0.009000             2.000000              9.000000     0.987110
# 25%       0.036000            23.000000            108.000000     0.991723
# 50%       0.043000            34.000000            134.000000     0.993740
# 75%       0.050000            46.000000            167.000000     0.996100
# max       0.346000           289.000000            440.000000     1.038980
#
#                 pH    sulphates      alcohol      quality
# count  4898.000000  4898.000000  4898.000000  4898.000000
# mean      3.188267     0.489847    10.514267     5.877909
# std       0.151001     0.114126     1.230621     0.885639
# min       2.720000     0.220000     8.000000     3.000000
# 25%       3.090000     0.410000     9.500000     5.000000
# 50%       3.180000     0.470000    10.400000     6.000000
# 75%       3.280000     0.550000    11.400000     6.000000
# max       3.820000     1.080000    14.200000     9.000000

# %%
red.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
pd.isnull(red).count()
# Out:
# fixed acidity           1599
# volatile acidity        1599
# citric acid             1599
# residual sugar          1599
# chlorides               1599
# free sulfur dioxide     1599
# total sulfur dioxide    1599
# density                 1599
# pH                      1599
# sulphates               1599
# alcohol                 1599
# quality                 1599
# dtype: int64

# %%
pd.isnull(white).count()
# Out:
# fixed acidity           4898
# volatile acidity        4898
# citric acid             4898
# residual sugar          4898
# chlorides               4898
# free sulfur dioxide     4898
# total sulfur dioxide    4898
# density                 4898
# pH                      4898
# sulphates               4898
# alcohol                 4898
# quality                 4898
# dtype: int64

# %%
# Add `type` column to `red` with value 1
red['type'] = 1

# Add `type` column to `white` with value 0
white['type'] = 0

# Append `white` to `red`
wines = red.append(white, ignore_index=True)
wines.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 6492                 24.0                  92.0  0.99114  3.27       0.50
# 6493                 57.0                 168.0  0.99490  3.15       0.46
# 6494                 30.0                 111.0  0.99254  2.99       0.46
# 6495                 20.0                 110.0  0.98869  3.34       0.38
# 6496                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality  type
# 6492     11.2        6     0
# 6493      9.6        5     0
# 6494      9.4        6     0
# 6495     12.8        7     0
# 6496     11.8        6     0

# %%
# Import `train_test_split` from `sklearn.model_selection`
from sklearn.model_selection import train_test_split

# Specify the data 
X=wines.iloc[:,0:11]

# Specify the target labels and flatten the array
y= np.ravel(wines.type)
#y= wines.type

# Split the data up in train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %%
y_test[0:10]
# Out:
# array([0, 1, 0, 0, 0, 1, 0, 0, 1, 0], dtype=int64)

# %%
# Import `StandardScaler` from `sklearn.preprocessing`
from sklearn.preprocessing import StandardScaler

# Define the scaler 
scaler = StandardScaler().fit(X_train)

# Scale the train set
X_train = scaler.transform(X_train)

# Scale the test set
X_test = scaler.transform(X_test)

# %%
X_train.size
# Out:
# 50017

# %% [markdown]
# # Deep Neural Network

# %%
# Using Tensorflow Keras instead of the original Keras



from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from keras.layers.advanced_activations import ReLU

# define the model architecture

# Initialize the constructor
model = Sequential()

# Add an input layer 
model.add(Dense(30, activation='relu', input_shape=(11,)))


# Add an output layer 
model.add(Dense(1, activation='sigmoid'))


# Add an input layer 
#model.add(Dense(10, activation='relu', input_shape=(11,)))

# Add an input layer 
#model.add(Dense(10, activation='relu', input_shape=(11,)))

# Add one hidden layer 
#model.add(Dense(8, activation='relu'))

# %% [markdown]
# 1. Keep the epochs 20
# 2. Keep the batch size 5000
# 3. Check the accuracy  (poor accuracy score, discuss)
#
# 4. Increase epochs to 40
# 5. Check the accuracy (high accuracy score , discuss)
#
# 6. Reduce batch size to 256
# 7. Reduce the epochs to 20
# 8. Check the accuracy score (90%+ discuss)
#
#
# 9. Add more hidden layers - what is the observation
#
# 10 Replace 'relu' with 'sigmoid' - what is the observation

# %%
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
                   

epochs = 40
batch_size = 50017


history = model.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, validation_split=.3, verbose=True)
loss,accuracy  = model.evaluate(X_test, y_test, verbose=False)
# Out:
# Train on 3182 samples, validate on 1365 samples
# Epoch 1/40
# 3182/3182 [==============================] - 0s 122us/sample - loss: 0.5908 - accuracy: 0.7546 - val_loss: 0.5873 - val_accuracy: 0.7626
# Epoch 2/40
# 3182/3182 [==============================] - 0s 8us/sample - loss: 0.5823 - accuracy: 0.7700 - val_loss: 0.5792 - val_accuracy: 0.7722
# Epoch 3/40
# 3182/3182 [==============================] - 0s 4us/sample - loss: 0.5740 - accuracy: 0.7806 - val_loss: 0.5713 - val_accuracy: 0.7853
# Epoch 4/40
# 3182/3182 [==============================] - 0s 4us/sample - loss: 0.5658 - accuracy: 0.7979 - val_loss: 0.5634 - val_accuracy: 0.8022
# Epoch 5/40
# 3182/3182 [==============================] - 0s 4us/sample - loss: 0.5577 - accuracy: 0.8105 - val_loss: 0.5557 - val_accuracy: 0.8168
# Epoch 6/40
# 3182/3182 [==============================] - 0s 4us/sample - loss: 0.5498 - accuracy: 0.8228 - val_loss: 0.5482 - val_accuracy: 0.8300
# Epoch 7/40
# 3182/3182 [==============================] - 0s 4us/sample - loss: 0.5420 - accuracy: 0.8328 - val_loss: 0.5407 - val_accuracy: 0.8403
# Epoch 8/40
# 3182/3182 [==============================] - 0s 5us/sample - loss: 0.5343 - accuracy: 0.8451 - val_loss: 0.5333 - val_accuracy: 0.8513
# Epoch 9/40
# 3182/3182 [==============================] - 0s 4us/sample - loss: 0.5267 - accuracy: 0.8532 - val_loss: 0.5261 - val_accuracy: 0.8586
# Epoch 10/40
# 3182/3182 [==============================] - 0s 4us/sample - loss: 0.5193 - accuracy: 0.8642 - val_loss: 0.5189 - val_accuracy: 0.8689
# Epoch 11/40
# 3182/3182 [==============================] - 0s 4us/sample - loss: 0.5120 - accuracy: 0.8715 - val_loss: 0.5119 - val_accuracy: 0.8784
# Epoch 12/40
# 3182/3182 [==============================] - 0s 4us/sample - loss: 0.5048 - accuracy: 0.8821 - val_loss: 0.5050 - val_accuracy: 0.8842
# Epoch 13/40
# 3182/3182 [==============================] - 0s 5us/sample - loss: 0.4977 - accuracy: 0.8884 - val_loss: 0.4982 - val_accuracy: 0.8894
# Epoch 14/40
# 3182/3182 [==============================] - 0s 4us/sample - loss: 0.4908 - accuracy: 0.8938 - val_loss: 0.4915 - val_accuracy: 0.8952
# Epoch 15/40
# 3182/3182 [==============================] - 0s 5us/sample - loss: 0.4840 - accuracy: 0.9001 - val_loss: 0.4849 - val_accuracy: 0.9011
# Epoch 16/40
# 3182/3182 [==============================] - 0s 5us/sample - loss: 0.4773 - accuracy: 0.9054 - val_loss: 0.4785 - val_accuracy: 0.9026
# Epoch 17/40
# 3182/3182 [==============================] - 0s 5us/sample - loss: 0.4707 - accuracy: 0.9117 - val_loss: 0.4721 - val_accuracy: 0.9092
# Epoch 18/40
# 3182/3182 [==============================] - 0s 5us/sample - loss: 0.4642 - accuracy: 0.9148 - val_loss: 0.4658 - val_accuracy: 0.9172
# Epoch 19/40
# 3182/3182 [==============================] - 0s 6us/sample - loss: 0.4578 - accuracy: 0.9189 - val_loss: 0.4596 - val_accuracy: 0.9216
# Epoch 20/40
# 3182/3182 [==============================] - 0s 6us/sample - loss: 0.4516 - accuracy: 0.9230 - val_loss: 0.4536 - val_accuracy: 0.9238
# Epoch 21/40
# 3182/3182 [==============================] - 0s 6us/sample - loss: 0.4454 - accuracy: 0.9268 - val_loss: 0.4476 - val_accuracy: 0.9260
# Epoch 22/40
# 3182/3182 [==============================] - 0s 5us/sample - loss: 0.4394 - accuracy: 0.9309 - val_loss: 0.4417 - val_accuracy: 0.9289
# Epoch 23/40
# 3182/3182 [==============================] - 0s 4us/sample - loss: 0.4334 - accuracy: 0.9324 - val_loss: 0.4359 - val_accuracy: 0.9311
# Epoch 24/40
# 3182/3182 [==============================] - 0s 6us/sample - loss: 0.4276 - accuracy: 0.9349 - val_loss: 0.4302 - val_accuracy: 0.9348
# Epoch 25/40
# 3182/3182 [==============================] - 0s 5us/sample - loss: 0.4218 - accuracy: 0.9381 - val_loss: 0.4246 - val_accuracy: 0.9377
# Epoch 26/40
# 3182/3182 [==============================] - 0s 5us/sample - loss: 0.4162 - accuracy: 0.9406 - val_loss: 0.4191 - val_accuracy: 0.9407
# Epoch 27/40
# 3182/3182 [==============================] - 0s 5us/sample - loss: 0.4106 - accuracy: 0.9428 - val_loss: 0.4137 - val_accuracy: 0.9407
# Epoch 28/40
# 3182/3182 [==============================] - 0s 6us/sample - loss: 0.4052 - accuracy: 0.9456 - val_loss: 0.4083 - val_accuracy: 0.9443
# Epoch 29/40
# 3182/3182 [==============================] - 0s 5us/sample - loss: 0.3998 - accuracy: 0.9478 - val_loss: 0.4031 - val_accuracy: 0.9465
# Epoch 30/40
# 3182/3182 [==============================] - 0s 5us/sample - loss: 0.3946 - accuracy: 0.9481 - val_loss: 0.3979 - val_accuracy: 0.9473
# Epoch 31/40
# 3182/3182 [==============================] - 0s 4us/sample - loss: 0.3894 - accuracy: 0.9497 - val_loss: 0.3928 - val_accuracy: 0.9495
# Epoch 32/40
# 3182/3182 [==============================] - 0s 4us/sample - loss: 0.3843 - accuracy: 0.9516 - val_loss: 0.3878 - val_accuracy: 0.9524
# Epoch 33/40
# 3182/3182 [==============================] - 0s 5us/sample - loss: 0.3793 - accuracy: 0.9532 - val_loss: 0.3829 - val_accuracy: 0.9538
# Epoch 34/40
# 3182/3182 [==============================] - 0s 5us/sample - loss: 0.3744 - accuracy: 0.9547 - val_loss: 0.3780 - val_accuracy: 0.9538
# Epoch 35/40
# 3182/3182 [==============================] - 0s 5us/sample - loss: 0.3695 - accuracy: 0.9566 - val_loss: 0.3733 - val_accuracy: 0.9538
# Epoch 36/40
# 3182/3182 [==============================] - 0s 4us/sample - loss: 0.3648 - accuracy: 0.9573 - val_loss: 0.3686 - val_accuracy: 0.9560
# Epoch 37/40
# 3182/3182 [==============================] - 0s 4us/sample - loss: 0.3601 - accuracy: 0.9573 - val_loss: 0.3639 - val_accuracy: 0.9568
# Epoch 38/40
# 3182/3182 [==============================] - 0s 4us/sample - loss: 0.3555 - accuracy: 0.9579 - val_loss: 0.3594 - val_accuracy: 0.9575
# Epoch 39/40
# 3182/3182 [==============================] - 0s 4us/sample - loss: 0.3509 - accuracy: 0.9585 - val_loss: 0.3549 - val_accuracy: 0.9582
# Epoch 40/40
# 3182/3182 [==============================] - 0s 4us/sample - loss: 0.3465 - accuracy: 0.9588 - val_loss: 0.3505 - val_accuracy: 0.9597

# %%
print(history.history['val_accuracy'])

print(history.history['accuracy'])

ta = pd.DataFrame(history.history['accuracy'])
va = pd.DataFrame(history.history['val_accuracy'])

tva = pd.concat([ta,va] , axis=1)

tva.boxplot()
# Out:
# [0.7626374, 0.7721612, 0.785348, 0.8021978, 0.8168498, 0.83003664, 0.84029305, 0.85128206, 0.85860807, 0.8688645, 0.8783883, 0.8842491, 0.8893773, 0.8952381, 0.9010989, 0.9025641, 0.9091575, 0.9172161, 0.9216117, 0.9238095, 0.92600733, 0.92893773, 0.93113554, 0.93479854, 0.93772894, 0.94065934, 0.94065934, 0.94432235, 0.94652015, 0.94725275, 0.94945055, 0.95238096, 0.95384616, 0.95384616, 0.95384616, 0.95604396, 0.95677656, 0.95750916, 0.95824176, 0.95970696]
# [0.7545569, 0.769956, 0.7806411, 0.79792583, 0.81049657, 0.822753, 0.83280957, 0.845066, 0.853237, 0.86423635, 0.8714645, 0.8821496, 0.88843495, 0.8937775, 0.90006286, 0.9054054, 0.9116908, 0.9148334, 0.9189189, 0.9230044, 0.92677563, 0.9308611, 0.9324324, 0.9349466, 0.93808925, 0.9406034, 0.94280326, 0.9456317, 0.9478316, 0.9481458, 0.94971716, 0.95160276, 0.9531741, 0.9547455, 0.95663106, 0.9572596, 0.9572596, 0.9578881, 0.95851666, 0.95883095]

# %%
y_pred = np.round(model.predict(X_test))

# %%
y_pred[0:10]
# Out:
# array([[0.],
#        [1.],
#        [0.],
#        [0.],
#        [0.],
#        [1.],
#        [0.],
#        [0.],
#        [1.],
#        [0.]], dtype=float32)

# %%
loss, acc = model.evaluate(X_test, y_test, verbose=0)
print('Test Accuracy: %.3f' % acc)


loss, acc = model.evaluate(X_train, y_train, verbose=0)
print('Test Accuracy: %.3f' % acc)
# Out:
# Test Accuracy: 0.971
# Test Accuracy: 0.959

# %%
from sklearn import metrics

print(pd.DataFrame(metrics.confusion_matrix(y_test, y_pred, labels=[0 ,1]), index=['true:White', 'true:Red'], columns=['pred:White', 'pred:Red']))
# Out:
#             pred:White  pred:Red
# true:White        1402        46
# true:Red            11       491

# %%
# %matplotlib inline
from matplotlib import pyplot
from numpy import where

# plot loss during training
pyplot.subplot(211)
pyplot.title('Loss')
pyplot.plot(history.history['loss'], label='train')
pyplot.legend()
